# %% [markdown]
# # Analiza i Bazy Danych - Laboratorium 1.
#
# **Karol Bakalarz**

# %% [markdown]
# **Zadanie 3**
#
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# $f(x)=x^2+5$
#
# $x>-1 \ oraz \ x<1$
#
# $x>-6 \  oraz \ x<6$
#
# $x>0 \ oraz \ x<5$
#
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt


# definicja funkcji odpowiadającej za obliczanie i rysowanie wykresu
def f(rng_l,rng_h):
    x = np.linspace(rng_l, rng_h, 500)
    y = x**2+5
    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Wykres')
    plt.grid(True)
    plt.show()

# %%
f(-1,1)

# %%
f(-6,6)

# %%
f(0,5)

# %% [markdown]
# **Zadanie 4**
#
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
import pandas as pd 

dataF = pd.DataFrame(np.array([['Jan', 'Kowalski', 25, 'female'], 
                            ['Maria', 'Nowaki', 65, 'male'],
                            ['Edyta', 'Potocki', 34, 'female'],
                            ['Krzysztof', 'Czarniecki', 20, 'male'],
                            ['Janusz', 'Mościcki', 31, 'male']]),
                            columns=['name', 'surname', 'age', 'sex'])

dataF
# Out:
#         name     surname age     sex
# 0        Jan    Kowalski  25  female
# 1      Maria      Nowaki  65    male
# 2      Edyta     Potocki  34  female
# 3  Krzysztof  Czarniecki  20    male
# 4     Janusz    Mościcki  31    male

# %%
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
# name       5 non-null object
# surname    5 non-null object
# age        5 non-null object
# sex        5 non-null object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %%
dataF.describe()
# Out:
#           name  surname age   sex
# count        5        5   5     5
# unique       5        5   5     2
# top     Janusz  Potocki  31  male
# freq         1        1   1     3

# %%
dataF.head(2)
# Out:
#     name   surname age     sex
# 0    Jan  Kowalski  25  female
# 1  Maria    Nowaki  65    male
