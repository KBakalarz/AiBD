# %%
import pandas as pd

# %%
df_weather = pd.read_fwf('weather.txt')
df_tb = pd.read_csv('tb.csv')
df_billboard = pd.read_csv('billboard.csv')
df_drinks = pd.read_csv('drinks.csv')
df_earthquake = pd.read_csv('earthquake_data.csv')

# %%
df_weather
# Out:
#       MX000017004195504TMAX  310    I  310.1  I.1  310.2  I.2  320  I.3  330  \
# 0     MX000017004195504TMIN  150    I    150    I    160    I  150    I  160
# 1     MX000017004195504PRCP    0    I      0    I      0    I    0    I    0
# 2     MX000017004195505TMAX  310    I    310    I    310    I  300    I  300
# 3     MX000017004195505TMIN  200    I    160    I    160    I  150    I  150
# 4     MX000017004195505PRCP    0    I      0    I      0    I    0    I    0
# ...                     ...  ...  ...    ...  ...    ...  ...  ...  ...  ...
# 1708  MX000017004201103TMIN  999  NaN    999  NaN    999  NaN  999  NaN  148
# 1709  MX000017004201103PRCP    0    S    999  NaN      0    S    0    S    0
# 1710  MX000017004201104TMAX  999  NaN    350    S    999  NaN  999  NaN  999
# 1711  MX000017004201104TMIN  999  NaN    168    S    999  NaN  999  NaN  999
# 1712  MX000017004201104PRCP    0    S      0    S    999  NaN  999  NaN    0
#
# ...

# %%
df_tb
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# ...   ...   ...      ...         ...          ...          ...           ...
# 5764   ZW  2004  14581.0         NaN          NaN        187.0         833.0
# 5765   ZW  2005  13155.0         NaN          NaN        210.0         837.0
# 5766   ZW  2006  12718.0         NaN          NaN        215.0         736.0
# 5767   ZW  2007  10583.0         6.0        132.0        138.0         500.0
# 5768   ZW  2008   9830.0         NaN          NaN        127.0         614.0
#
# ...

# %%
df_billboard
df_billboard.sort_values('date.entered')
df_billboard.sort_values('artist.inverted')
# Out:
#      year   artist.inverted  \
# 246  2000             2 Pac
# 287  2000           2Ge+her
# 24   2000      3 Doors Down
# 193  2000      3 Doors Down
# 69   2000          504 Boyz
# ..    ...               ...
# 254  2000       Yankee Grey
# 277  2000  Yearwood, Trisha
# 251  2000   Ying Yang Twins
# 314  2000     Zombie Nation
# 15   2000   matchbox twenty
#
#                                                  track  time    genre  \
# 246                Baby Don't Cry (Keep Ya Head Up II)  4:22      Rap
# 287  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15      R&B
# 24                                          Kryptonite  3:53     Rock
# 193                                              Loser  4:24     Rock
# 69                                       Wobble Wobble  3:35      Rap
# ..                                                 ...   ...      ...
# 254                               Another Nine Minutes  3:10  Country
# ...
